# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelAnga/MachineLearning_Bootcamp/blob/main/natural_language_processing_pipeline_Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from textblob import TextBlob

from imblearn.pipeline import Pipeline as ImbPipeline
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Importing the dataset

# %%
#Connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os #Libary necesary for accessing the folder
os.chdir('/content/drive/MyDrive/Machine Learning/NLP/DataSets')

os.listdir()
# Out:
# ['Restaurant_Reviews.tsv']

# %%
dataset = pd.read_csv('Restaurant_Reviews.tsv', delimiter = '\t', quoting = 3) #quoting = 3 ignores the quotes

# %% [markdown]
# ## Cleaning the texts

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer #Transform words into their base from (loved -> love) -> into Present tense
corpus = []

#iterates indexes
for i in range(0, 1000):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
  review = review.lower()
  review = review.split() #splits review into different words -------> ask chatgpt
  ps = PorterStemmer()
  #Used to remove 'not' from stopwords
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  #review = [ps.stem(word) for word in review if len(word) > 2 and word not in set(all_stopwords)]
  #review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = [re.sub(r'(.)\1+', r'\1', word) for word in review]
  review = [str(TextBlob(word).correct()) for word in review]

  custom_stopwords = {'food', 'place', 'service', 'restaurant', 'menu', 'server', 'staff'}
  review = [word for word in review if word not in custom_stopwords]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus
# Out:
# ['now loved this',
#  'crust is not god',
#  'not taste and the texture was just nasty',
#  'stopped by during the late may bank holiday of rich steve recommendation and loved it',
#  'the selection on the was great and so were the prices',
#  'now i am getting angry and i want my damn who',
#  'honestly it didn t taste that fresh',
#  'the potatoes were like rubber and you could tell they had ben made up ahead of time being kept under a warmer',
#  'the fires were great to',
#  'a great touch',
#  'was very prompt',
#  'would not go back',
#  'the cashier had no care what so ever on what i had to say it still ended up being way overpriced',
#  'i tried the cape cod revolt chicken with chancery m',
#  'i was disgusted because i was pretty sure that was human hair',
#  'i was shocked because no signs indicate cash only',
#  'highly recommended',
#  'waited was a little slow in',
#  'this is not worth your time let alone began',
#  'did not like at al',
#  'the bursitis bah',
#  'the for amazing',
#  'is also cut',
#  'i could care les the interior is just beautiful',
#  'so they performed',
#  'that s right the red velvet cake oh this stuff is so god',
#  'they never brought a salad we asked for',
#  'this hole in the was has great mexican street faces and friendly',
#  'to an hour to get our for only tables in my for was luke warm our never was running around like he was total overwhelmed',
#  'the worst was the salmon sashimi',
#  'also there are combs like a burgher fires and be for which is a decent deal',
#  'this was like the final blow',
#  'i found this by accident and i could not be happier',
#  'seems like a god quick to grab a bite of some familiar pub for but do yourself a favor and look elsewhere',
#  'overall i like this a lot',
#  'the only redeeming quality of the was that it was very expensive',
#  'ample portions and god prices',
#  'for the waiter made me felt like i was stupid every time he came to the table',
#  'my first visit to hero was a delight',
#  'sucks',
#  'the shrimp tender and moist',
#  'there is not a deal god enough that would drag me into that establishment again',
#  'hard to judge whether these sides were god because we were rose out by the melted styrofoam and didn t want to eat it for fear of getting sick',
#  'on a positive note our was very attentive and provided great',
#  'frozen packs of disgust with some of the worst people behind the register',
#  'the only thing i did like was the prime rib and desert section',
#  'it s to bad the for is so damn genetic',
#  'the burgher is god be choked just right',
#  'if you want a sandwich just go to any warehouse',
#  'my side grew salad with the grew dressing was so taste and the pity and human was very refreshing',
#  'we ordered the duck rare and it was pink and tender on the inside with a nice chair on the outside',
#  'he came running after us when he realized my husband had left his sunglases on the table',
#  'their how mein is so god',
#  'they have horrible attitudes towards customers and talk down to each one when customers don t enjoy their for',
#  'the portion was huge',
#  'loved it friendly serves great for wonderful and imaginative',
#  'the heart attack girl in downtown began is an absolutely flat lined excuse for a',
#  'not much seated and like strings of past at the bottom',
#  'the salad had just the right amount of sauce to not over power the scalp which was perfectly choked',
#  'the wiped banana was not only wiped but petrified and tastes',
#  'at least think to refill my water before i struggle to wave you over for minutes',
#  'this receives stars for their apetizers',
#  'the cocktail are al handmade and delicious',
#  'we d definitely go back here again',
#  'we are so glad we found this',
#  'great for and huge portions and they give a military discount',
#  'always a great time at do rings',
#  'update went back for a second time and it was still just as amazing',
#  'we got the for and apparently they have never heard of salt and the later on the fish was chew',
#  'a great way to finish a great',
#  'the deal included hastings and drinks and je went above and beyond what we expected',
#  'really really god rice al the time',
#  'the was me',
#  'it to over min to get their milkshake which was nothing more than chocolate milk',
#  'i guns i should have known that this would suck because it is inside of the excalibur but i didn t use my common sense',
#  'the scalp dish is quite healing for value as we',
#  'times very bad customer',
#  'the set potato fires were very god and seasoned we',
#  'today is the second time i ve ben to their lunch but and it was pretty god',
#  'there is so much god for in began that i felt created for wasting an eating opportunity by going to rice and company',
#  'coming here is like experiencing an underwhelming relationship where both parties can t wait for the other person to ask to break up',
#  'walked in and the smiled like an old grease trap and only others there eating',
#  'the turkey and roast be were bland',
#  'this has it',
#  'the pan cakes everyone are raving about taste like a sugary disaster tailor to the palate of a six year old',
#  'i love the who and the spring role oh so yuma you have to try',
#  'the for later to meat ratio made the chicken tenders very satisfying',
#  'al i have to say is the for was amazing',
#  'omelet are to die for',
#  'everything was fresh and delicious',
#  'in summary this was a largely disappointing dining experience',
#  'it s like a really sex party in your mouth where you re outrageous flirting with the honest person at the party',
#  'never ben to hard rock causing before will never ever step forward in it again',
#  'best breakfast but',
#  'say bye bye to your tip lady',
#  'we l never go again',
#  'will be back again',
#  'for arrived quickly',
#  'it was not god',
#  'on the up side their cafe serves really god for',
#  'our was fantastic and when he found out the wife loves roasted garlic and bone marrow he added extra to our meal and another marrow to go',
#  'the only god thing was our waiter he was very helpful and kept the body mary s coming',
#  'best but in town for the price you cannot beat it',
#  'i loved their myself choked in this wine reduction the duck was tender and their potato dishes were delicious',
#  'this is one of the better buffets that i have ben to',
#  'so we went to tigerlily and had a fantastic afternoon',
#  'the for was delicious our bartender was attentive and personal and we got a great deal',
#  'the absence is wonderful and there is music playing',
#  'will go back next trip out',
#  'so god',
#  'real such lovers let s be honest yuma is not that god',
#  'at least min passed in between us ordering and the for driving and it wasn t that busy',
#  'this is a really fantastic that which is definitely worth a visit',
#  'nice spice and tender',
#  'god prices',
#  'check it out',
#  'it was pretty gros',
#  'i ve had better atmosphere',
#  'kind of hard to me up a speak but they did',
#  'although i very much liked the look and sound of this the actual experience was a bit disappointing',
#  'i just don t know how this managed to served the blankets for i have ever eaten when they are preparing indian quinine',
#  'worst to not but that is the least of their tories',
#  'was fine and the waited was friendly',
#  'the guns al had speaks and our speak loving son who has had speak at the best and worst places said it was the best speak he s ever eaten',
#  'we thought you d have to venture further away to get god such but this really hit the spot that night',
#  'host were for lack of a better word birches',
#  'bland not a liking this for a number of reasons and i don t want to waste time on bad reviewing i l leave it at that',
#  'phenomena for and alliance',
#  'i wouldn t return',
#  'definitely worth venturing of the strip for the pork bell will return next time i m in began',
#  'this is way to overpriced for mediocre for',
#  'pen vodka excellent',
#  'they have a god selection of for including a massive meatloaf sandwich a crisp chicken wrap a relish tune melt and some taste burghers',
#  'the management is rude',
#  'delicious ny wages god selections of cream these real low with capers even',
#  'great subways in fact it s so god when you come here every other subways will not met your expectations',
#  'i had a seriously solid breakfast here',
#  'this is one of the best bars with for in began',
#  'he was extremely rude and really there are so many other i would love to dine at during a weekend in began',
#  'my drink was never empty and he made some really great suggestions',
#  'don t do it',
#  'the waiter wasn t helpful or friendly and rarely checked on us',
#  'my husband and i ate lunch here and were very disappointed with the for and',
#  'and the red cry had so much bamboo shots and wasn t very taste to me',
#  'nice blanket of mon over top but i felt like this was done to cover up the supper for',
#  'the bathroom are clean and the itself is we decorated',
#  'the is always changing for quality is going down is extremely slow',
#  'the was a little slow considering that were served by people serves so the for was coming in a slow pace',
#  'i give it thumbs down',
#  'we watched our waiter pay a lot more attention to other tables and ignore us',
#  'my fiance and i came in the middle of the day and we were greeted and seated right away',
#  'this is a great at the mandalay bay',
#  'we waited for forty five minutes in vain',
#  'crossing that came with the salad was stale',
#  'some highlight great quality nigiri here',
#  'the is friendly and the joint is always clean',
#  'this was a different cut than the piece the other day but still wonderful and tender s we as we favored',
#  'i ordered the do past and it was the first time i d had really excellent past since going lumen are several years ago',
#  'this is god',
#  'unfortunately we must have hit the baker on leftover day because everything we ordered was stale',
#  'i came back today since they related and still not impressed',
#  'i was seated immediately',
#  'their is diverse and reasonably prices',
#  'avoid at al cost',
#  'is always full but never a wait',
#  'delicious',
#  'this is hands down one of the best places to eat in the phoenix retro area',
#  'so don t go there if you are looking for god for',
#  'i ve never ben treated so bad',
#  'bacon is held salt',
#  'we also ordered the spinal and avocado salad the ingredient were sad and the dressing literary had zero taste',
#  'this really is how began fine dining used to be right down to the venus handed to the ladies that have no prices listed',
#  'the waitresses are very friendly',
#  'lord the khan so is a dish that is not to be mixed for cry lovers',
#  'everything on the is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter',
#  'perhaps i caught them on an of night judging by the other reviews but i m not inspired to go back',
#  'the here leaves a lot to be desired',
#  'the atmosphere is modern and hip while maintaining a touch of copies',
#  'not a weekly haunt but definitely a to come back to every once in a while',
#  'we literary sat there for minutes with no one asking to take our order',
#  'the burgher had absolutely no flavor the meat itself was total bland the burgher was overcome and there was no charcoal flavor',
#  'i also decided not to send it back because our waited looked like she was on the verge of having a heart attack',
#  'i dressed up to be treated so rudely',
#  'it was probably dirt',
#  'love this hits the spot when i want something healthy but not lacking in quantity or flavor',
#  'i ordered the lemon raspbery ice cocktail which was also incredible',
#  'the for sucked which we expected but it sucked more than we could have imagined',
#  'interesting door',
#  'what i really like there is the crept station',
#  'also were served hot bread and outer and home made potato chips with bacon bits on top very original and very god',
#  'you can watch them preparing the delicious for',
#  'both of the eg role were fantastic',
#  'when my order arrived one of the gros was rising',
#  'i had a salad with the wings and some ice cream for desert and left feeling quite satisfied',
#  'i m not really sure how joy s was voted best hot dog in the valley by readers of phoenix magazine',
#  'the best to go for a taste bowl of who',
#  'the live music on friday total blows',
#  'i ve never ben more insulted or felt disrespected',
#  'very friendly',
#  'it is worth the drive',
#  'i had heard god things about this but it exceeding every hope i could have dreamed of',
#  'for was great and so was the',
#  'the warm be didn t help',
#  'great branch spot',
#  'is friendly and inviting',
#  'very god lunch spot',
#  'i ve lived here since and this was the first and last time i ve stepped for into this',
#  'the worst experience ever',
#  'must have ben an of night at this',
#  'the sides are relish mixed mushrooms upon gold pure white corn beateous',
#  'if that bug never showed up i would have given a for sure but on the other side of the was where this bug was climbing was the kitchen',
#  'for about minutes we we re waiting for her salad when we realized that it wasn t coming any time son',
#  'my friend loved the salmon tartar',
#  'won t go back',
#  'extremely taste',
#  'waited was god though',
#  'so and not god',
#  'the jamaica monitor are delicious',
#  'which are small and not worth the price',
#  'the for is rich so order accordingly',
#  'the shower area is outside so you can only rise not take a full shower unless you don t mind being rude for everyone to se',
#  'the was a bit lacking',
#  'lobster tissue bushel sprout riot file al need salt and paper and of course there is none at the tables',
#  'hopeful this bodes for them going out of business and someone who can co can come in',
#  'it was either to cold not enough flavor or just bad',
#  'i loved the bacon wrapped dates',
#  'this is an unbelievable bargain',
#  'the folks at to always make us felt so welcome and special',
#  'as for the mains also inspired',
#  'this is the where i first had who and it was amazing',
#  'this wonderful experience made this a must stop whenever we are in town again',
#  'if the for isn t bad enough for you then enjoy dealing with the world s worst annoying drunk people',
#  'very very fun chef',
#  'ordered a double cheseburger got a single party that was falling apart picture unloaded yeah still sucks',
#  'great to have a couple drinks and watch any and al sporting events as the was are covered with to s',
#  'if it were possible to give them zero stars they d have it',
#  'the descriptions said sum sum sauce and another said el sauce yet another said spice mayo we none of the role had fauces on them',
#  'i d say that would be the hardest decision honestly al of m s dishes taste how they are supposed to taste amazing',
#  'if she had not role the eyes we may have stayed not sure if we will go back and try it again',
#  'everyone is very attentive providing excellent customer',
#  'horrible don t waste your time and money',
#  'now this dish was quite flavourful',
#  'by this time our side of the was almost empty so there was no excuse',
#  'it wasn t busy either also the building was freezing cold',
#  'like the other reviewed said you couldn t pay me to eat at this again',
#  'drinks to close to minutes to come out at one point',
#  'seriously flavorful delights folks',
#  'much better than the other aye such i went to in began',
#  'the lighting is just dark enough to set the god',
#  'based on the sub par i received and no effort to show their gratitude for my business i won t be going back',
#  'owner s are really great people',
#  'there is nothing privileged about working eating there',
#  'the grew dressing was very creamy and flavorful',
#  'overall i don t think that i would take my parents to this again because they made most of the similar complaints that i silently felt to',
#  'now the liza itself was god the peanuts sauce was very taste',
#  'we had at our table and the was pretty fast',
#  'fantastic here',
#  'i as we would ve given godfather zero stars if possible',
#  'they know how to make them here',
#  'very tough and very short on flavor',
#  'i hope this sticks around',
#  'i have ben in more than a few bars in began and do not ever real being charged for tap water',
#  'the atmosphere was exquisite',
#  'god very clean and expensive to not',
#  'the seated was fresh and generous in portion',
#  'plus it s only bucks',
#  'the was not up to par either',
#  'thus far have only visited twice and the for was absolutely delicious each time',
#  'just as god as when i had it more than a year ago',
#  'for a self proclaimed come cafe i was wildly disappointed',
#  'the vegetarian later is out of this world',
#  'you can go wrong with any of the for here',
#  'you can t beat that',
#  'stopped by this while in madison for the roman very friendly kind',
#  'the chess were friendly and did a god job',
#  'i ve had better not only from dedicated bob tea spots but even from jena who',
#  'i liked the ratio and the was outstanding',
#  'the goat tact didn t skin on the meat and now what flavor',
#  'i think not again',
#  'i had the mac salad and it was pretty bland so i will not be getting that again',
#  'i went to bache burgher on a friend s recommendation and was not disappointed',
#  'sticks here',
#  'i waited and waited',
#  'this is not quality such it is not a quality',
#  'i would definitely recommend the wings as we as the liza',
#  'great liza and salad',
#  'things that went wrong they burned the saganaki',
#  'we waited an hour for what was a breakfast i could have done times better at home',
#  'this is amazing',
#  'i hate to disagree with my fellow elders but my husband and i were so disappointed with this',
#  'waited hours never got either of our pas as many other around us who came in later did',
#  'just don t know why they were so slow',
#  'the is great the for is relish and they have an incredible be selection',
#  'i live in the neighborhood so i am disappointed i won t be back here because it is a convenient location',
#  'i didn t know pulled pork could be so delicious',
#  'you get incredibly fresh fish prepared with care',
#  'before i go in to why i gave a star rating please know that this was my third time eating at bache burgher before writing a review',
#  'i love the fact that everything on their is worth it',
#  'never again will i be dining at this',
#  'the for was excellent and was very god',
#  'god be drink selection and god for selection',
#  'please stay away from the shrimp stir fried nodules',
#  'the potato chip order was sad i could probably count how many chips were in that box and it was probably around',
#  'for was really boring',
#  'god check',
#  'this grey corporation will never se another time from me',
#  'will never ever go back',
#  'as much as i d like to go back i can t get passed the atrocious and will never return',
#  'in the summer you can dine in a charming outdoor ratio so very delightful',
#  'i did not expect this to be so god',
#  'fantastic for',
#  'she ordered a boasted english mucin that came out untoasted',
#  'the for was very god',
#  'never going back',
#  'great for for the price which is very high quality and house made',
#  'the bus boy on the other hand was so rude',
#  'by this point my friends and i had basically figured out this was a joke and didn t mind making it publicly and loudly known',
#  'back to god by lighter fare reasonable pricking and tell the public they are back to the old ways',
#  'and considering the two of us left there very full and happy for about you just can t go wrong',
#  'al the bread is made in house',
#  'the only downside is the',
#  'also the fires are without a doubt the worst fires i ve ever had',
#  'was exceptional and for was a god as al the reviews',
#  'a couple of months later i returned and had an amazing meal',
#  'favorite in town for shawarma',
#  'the black eyed peas and set potatoes unreal',
#  'you won t be disappointed',
#  'they could serve it with just the vinaigrette and it may make for a better overall dish but it was still very god',
#  'i go to far to many places and i ve never men any that serves a eg breakfast especially for',
#  'when my mon and i got home she immediately got sick and she only had a few bites of salad',
#  'the serves are not pleasant to deal with and they don t always honor liza hut coupon',
#  'both of them were truly unbelievably god and i am so glad we went back',
#  'we had fantastic and were pleased by the atmosphere',
#  'everything was gros',
#  'i love this',
#  'great and for',
#  'first the bathroom at this location were dirty seat covers were not replenished just plain lucky',
#  'the burgher i got the gold standard a burgher and was kind of disappointed',
#  'org the for was delicious',
#  'there is nothing authentic about this',
#  'the spagheti is nothing special whatsoever',
#  'of al the dishes the salmon was the best but al were great',
#  'the vegetables are so fresh and the sauce felt like authentic that',
#  'it s worth driving up from tucson',
#  'the selection was probably the worst i ve men in began there was none',
#  'pretty god be selection to',
#  'this is like chipotle but better',
#  'class warm atmosphere fun and fresh apetizers purulent speaks basal speak',
#  'stars for the brick oven bread a',
#  'i have eaten here multiple times and each time the for was delicious',
#  'we sat another ten minutes and finally gave up and left',
#  'he was terrible',
#  'everyone is treated equal special',
#  'it shouldn t take min for pancake and legs',
#  'it was delicious',
#  'on the god side the was genuinely pleasant and enthusiastic a real treat',
#  'sadly gordon raised s speak is a we shall sharply avoid during our next trip to began',
#  'as always the evening was wonderful and the for delicious',
#  'best fish i ve ever had in my life',
#  'the bathroom is just next for and very nice',
#  'the but is small and al the for they offered was bland',
#  'this is an outstanding little with some of the best for i have ever tasted',
#  'pretty col i would say',
#  'definitely a turn of for me i doubt i l be back unless someone else is buying',
#  'did a great job handling our large rowdy table',
#  'i find wasting for to be despicable but this just wasn t for',
#  'my wife had the lobster tissue soup which was lukewarm',
#  'would come back again if i had a such craving while in began',
#  'the are great the alliance is great',
#  'he deserves stars',
#  'i left with a stomach ache and felt sick the rest of the day',
#  'they dropped more than the bal',
#  'the dining space is tiny but elegantly decorated and comfortable',
#  'they will customize your order any way you d like my usual is plant with grew bean stir cry love it',
#  'and the beans and rice were mediocre at best',
#  'best faces in town by far',
#  'i to back my money and got out there',
#  'in an interesting part of town this is amazing',
#  'rude considerate management',
#  'the are now not as friendly the wait times for being served are horrible no one even says hi for the first minutes',
#  'i won t be back',
#  'they have great miners',
#  'the was outlining i definitely recommend the halibut',
#  'the for was terrible',
#  'will never ever go back and have told many people what had happened',
#  'i don t recommend unless your car breaks down in front of it and you are starving',
#  'i will come back here every time i m in began',
#  'this deserves one star and has to do with the for',
#  'this is a disgrace',
#  'def coming back to bowl next time',
#  'if you want healthy authentic or ethics for try this',
#  'i will continue to come here on ladies night and date night highly recommend this to anyone who is in the area',
#  'i have ben here several times in the past and the experience has always ben great',
#  'we walked away stuffed and happy about our first began but experience',
#  'was excellent and prices are pretty reasonable considering this is began and located inside the crystals showing mal by area',
#  'to summarize the for was incredible nay transcendant but nothing brings me joy quite like the memory of the rheumatic condiments dispense',
#  'i m probably one of the few people to ever go to dans and not like it',
#  'kiss liza is always a hit to with lots of great side dish option for the sides',
#  'is perfect and the family atmosphere is nice to se',
#  'choked to perfection and the was implacable',
#  'this one is simply a disappointment',
#  'overall i was very disappointed with the quality of for at cochon',
#  'i don t have to be an accountant to know i m getting screwed',
#  'great to eat reminds me of the little mon and pop shops in the san francisco bay area',
#  'today was my first taste of a buldogis gourmet hot dog and i have to tell you it was more than i ever thought possible',
#  'left very frustrated',
#  'i l definitely be in son again',
#  'for was really god and i got full petya fast',
#  'was fantastic',
#  'total waste of time',
#  'i don t know what kind it is but they have the best ice tea',
#  'come hungry leave happy and stuffed',
#  'for i give them no stars',
#  'i can sure you that you won t be disappointed',
#  'i can take a little bad but the for sucks',
#  'gave up trying to eat any of the crust teeth still sore',
#  'but now i was completely rose out',
#  'i really enjoyed eating here',
#  'first time going but i think i will quickly become a regular',
#  'our was very nice and even though he looked a little overwhelmed with al of our news he stayed professional and friendly until the end',
#  'from what my dinner companions told me everything was very fresh with nice texture and taste',
#  'on the ground right next to our table was a large smeared ben stepped in and traced everywhere pile of grew bird pop',
#  'furthermore you can t even find hours of operation on the webster',
#  'we ve tried to like this but after times i think we re done with them',
#  'what a mistake that was',
#  'no complaints',
#  'this is some seriously god liza and i m an expert monsieur on the topic',
#  'waiter was a jerk',
#  'strike who wants to be rushed',
#  'these are the nicest owners i ve ever come across',
#  'i never come again',
#  'we loved the biscuits',
#  'is quick and friendly',
#  'ordered an apetizer and to minutes and then the liza another minutes',
#  'so absolutely fantastic',
#  'it was a huge awkward lb piece of cow that was the whistle and fat',
#  'definitely will come back here again',
#  'i like sterner because it s dark and it felt like a bar',
#  'now very spice but delicious',
#  'if you re not familiar check it out',
#  'i l take my business dinner dollars elsewhere',
#  'i d love to go back',
#  'anyway this is has a wonderful breakfast lunch',
#  'nothing special',
#  'each day of the we they have a different deal and it s al so delicious',
#  'not to mention the combination of years almonds and bacon is a big wine',
#  'will not be back',
#  'sauce was tastes',
#  'the for is delicious and just spice enough so be sure to ask for species if you prefer it that way',
#  'my ribeye speak was choked perfectly and had great mesquite flavor',
#  'i don t think we l be going back daytime son',
#  'for was so god',
#  'i am far from a such connoisseur but i can definitely tell the difference between god for and bad for and this was certainly bad for',
#  'i was so insulted',
#  'the last times i had lunch here has ben bad',
#  'the chicken wings contained the priest chicken meat i have ever eaten',
#  'the for was very god and i enjoyed every youthful an enjoyable relaxed venue for couples small family groups etc',
#  'agile i think you are great',
#  'best later toes in the southwest',
#  'we loved the',
#  'definitely not worth the i paid',
#  'the manila ice cream was creamy and smooth while the profiterole hour pantry was fresh enough',
#  'in in a al the time and now have my new spot',
#  'the manager was the worst',
#  'the inside is really quite nice and very clean',
#  'the for was outstanding and the prices were very reasonable',
#  'i don t think i l be running back to early s daytime son for for',
#  'this is was due to the fact that it to minutes to be acknowledged then another minutes to get our for and they kept forgetting things',
#  'love the margaritas to',
#  'this was my first and only began but and it did not disappoint',
#  'very god though',
#  'the one down note is the ventilator could use some upbraiding',
#  'great pork sandwich',
#  'don t waste your time here',
#  'total letdown i would much rather just go to the camelback flower shop and carted come',
#  'third the these on my friend s burgher was cold',
#  'we enjoy their liza and branch',
#  'the speaks are al we tried and also perfectly choked',
#  'we had a group of when we claimed we would only have and they handled us beautiful',
#  'i loved it',
#  'we asked for the bill to leave without eating and they didn t bring that either',
#  'this is a jewel in las began and exactly what i ve ben hoping to find in nearly ten years living here',
#  'seated was limited to boiled shrimp and crab legs but the crab legs definitely did not taste fresh',
#  'the selection of for was not the best',
#  'delicious and i will absolutely be back',
#  'this isn t a small family this is a fine dining establishment',
#  'they had a too tartar with a cuvier that was extraordinary and i liked the thinly slice way with white trifle',
#  'i dont think i will be back for a very long time',
#  'it was attached to a gas station and that is rarely a god sign',
#  'how awesome is that',
#  'i will be back many times son',
#  'the had so much god stuff on it i could not decide',
#  'worse of al he humiliated his worker right in front of me bunch of horrible name palings',
#  'conclusion very filing meals',
#  'their daily special are always a hit with my group',
#  'and then tragedy struck',
#  'the pancake was also really god and pretty large at that',
#  'this was my first crawfish experience and it was delicious',
#  'their monster chicken fried speak and legs is my al time favorite',
#  'waited was set and funny',
#  'i also had to taste my mon s multi grain pushkin pancake with can outer and they were amazing fluffy and delicious',
#  'i d rather eat airline for seriously',
#  'can say enough god things about this',
#  'the alliance was incredible',
#  'the waited and manager are so friendly',
#  'i would not recommend this',
#  'overall i wasn t very impressed with noma',
#  'my go was basically reduce only',
#  'terrible',
#  'thoroughly disappointed',
#  'i don t each much past but i love the homemade hand made parts and thin pas here',
#  'give it a try you will be happy you did',
#  'by far the best chesecurds we have ever had',
#  'reasonably prices also',
#  'everything was perfect the night we were in',
#  'the for is very god for your typical bar for',
#  'it was a drive to get there',
#  'at first glance it is a lovely baker cafe nice alliance clean friendly',
#  'anyway i do not think i will go back there',
#  'point your finger at any item on the order it and you won t be disappointed',
#  'oh this is such a thing of beauty this',
#  'if you haven t gone here go now',
#  'a greasy unhealthy meal',
#  'first time there and might just be the last',
#  'those burghers were amazing',
#  'similarly the delivery man did not say a word of apology when our for was minutes late',
#  'and it was way to expensive',
#  'be sure to order desert even if you ned to pack it to go the tiramisu and canal are both to die for',
#  'this was my first time and i can t wait until the next',
#  'the bartender was also nice',
#  'everything was god and taste',
#  'this is two thumbs up way up',
#  'the best in began for breakfast just check out a sat or sun',
#  'if you love authentic mexican for and want a whole bunch of interesting yet delicious meats to chose from you ned to try this',
#  'terrible management',
#  'an excellent new by an experienced frenchman',
#  'if there were zero stars i would give it zero stars',
#  'great speak great sides great wine amazing deserts',
#  'worst martin ever',
#  'the speak and the shrimp are in my opinion the best enters at go',
#  'i had the opportunity today to sample your amazing pas',
#  'we waited for thirty minutes to be seated although there were vacant tables and we were the only folks waiting',
#  'the yelowtail carpacio was melt in your mouth fresh',
#  'i won t try going back there even if it s empty',
#  'no i m going to eat the potato that i found some strangers hair in it',
#  'just spice enough perfect actual',
#  'last night was my second time dining here and i was so happy i decided to go back',
#  'not even a held we will be right with you',
#  'the deserts were a bit strange',
#  'my boyfriend and i came here for the first time on a recent trip to began and could not have ben more pleased with the quality of for and',
#  'i really do recommend this you can go wrong with this dont',
#  'nice alliance',
#  'i would recommend saving from for this',
#  'i guns maybe we went on an of night but it was disgraceful',
#  'however my recent experience at this particular location was not so god',
#  'i know this is not like the other at al something is very of here',
#  'avoid this establishment',
#  'i think this suffers from not trying hard enough',
#  'al of the taras dishes were delicious',
#  'i heart this',
#  'my salad had a bland vinegrete on the baby great and hearts of palm',
#  'after two i felt disgusting',
#  'a god time',
#  'i believe that this is a great stop for those with a huge bell and wandering for such',
#  'generous portions and great taste',
#  'i will never go back to this and will never ever recommended this to anyone',
#  'the serves went back and forth several times not even so much as an are you being helped',
#  'for was delicious',
#  'an hour seriously',
#  'i consider this theft',
#  'we this location news a complete overhauled',
#  'we recently witnessed her for quality of management towards other guests as we',
#  'waited and waited and waited',
#  'he also came back to check on us regularly excellent',
#  'our was super nice and checked on us many times',
#  'the liza tasted old super chew in not a god way',
#  'i swung in to give them a try but was reply disappointed',
#  'was god and the company was better',
#  'the are also very friendly and efficient',
#  'as for the i m a fan because it s quick and you re being served by some nice folks',
#  'boy was that sucked dry',
#  'over rate',
#  'if you look for authentic that for go else where',
#  'their speaks are recommended',
#  'after i pulled up my car i waited for another minutes before being acknowledged',
#  'great for and great in a clean and friendly seeing',
#  'al in al i can sure you i l be back',
#  'i hate those things as much as cheap quality black lives',
#  'my breakfast was prepared great with a beautiful presentation of giant slices of toast lightly dusted with powdered sugar',
#  'the kiss play area is nasty',
#  'great fo take out or eat in',
#  'the waited was friendly and happy to accommodate for began vein option',
#  'org i felt like i had never eaten that for until this dish',
#  'it was extremely crumbly and pretty tastes',
#  'it was a pale color instead of nice and chair and has no flavor',
#  'the croupous also taste homemade which is an extra plus',
#  'i got home to se the priest damn wings ever',
#  'it l be a regular stop on my trips to phoenix',
#  'i really enjoyed cream can before they expanded i even told friends they had the best breakfast',
#  'not god for the money',
#  'i his it and wish they had one in philadelphia',
#  'we got sitting fairly fast but ended up waiting minutes just to our order another minutes before the for arrived',
#  'they also have the best these crisp in town',
#  'god value great for great',
#  'couldn t ask for a more satisfying meal',
#  'the for is god',
#  'it was awesome',
#  'i just wanted to leave',
#  'we made the drive al the way from north scotsdale and i was not one bit disappointed',
#  'i will not be eating there again',
#  'the owners really really ned to quit being so cheap let them wrap my breaking sandwich in two papers not one',
#  'i checked out this a couple years ago and was not impressed',
#  'the chicken i got was definitely repeated and was only ok the edges were cold and so',
#  'story i will not be getting for from here daytime son',
#  'an absolute must visit',
#  'the cow tongue and cheek faces are amazing',
#  'my friend did not like his body mary',
#  'despite how hard i rate business its actual rare for me to give a star',
#  'they really want to make your experience a god one',
#  'i will not return',
#  'i had the chicken who and it tasted very bland',
#  'very disappointing',
#  'the cried chicken was so tender and below from the saffron reasoning',
#  'a drive thou means you do not want to wait around for half an hour for your for but somehow when we end up going here they make us wait and wait',
#  'pretty awesome',
#  'absence is perfect',
#  'best of luck to the rude and non customer focused new management',
#  'any grandmother can make a roasted chicken better than this one',
#  'i asked multiple times for the wine list and after some time of being ignored i went to the hostess and got one myself',
#  'the is always super friendly and helpful which is especially col when you bring two small boys and a baby',
#  'four stars for the for the guy in the blue shirt for his great vice still letting us in to eat',
#  'the roast be sandwich tasted really god',
#  'same evening him and i are both drasticaly sick',
#  'high quality chicken on the chicken caesar salad',
#  'ordered burgher rare came in we l done',
#  'we were promptly greeted and seated',
#  'tried to go here for lunch and it was a madhouse',
#  'i was prove dead wrong by this such bar not only because the quality is great but the is fast and the for implacable',
#  'after waiting an hour and being seated i was not in the greatest of mode',
#  'this is a god joint',
#  'the macarons here are insanely god',
#  'i m not eating here',
#  'our waiter was very attentive friendly and information',
#  'maybe if they weren t cold they would have ben somewhat enable',
#  'this has a lot of promise but fails to deliver',
#  'very bad experience',
#  'what a mistake',
#  'for was average at best',
#  'great for',
#  'we won t be going back daytime son',
#  'very very disappointed ordered the big bay later',
#  'great to relax and have an awesome burgher and be',
#  'it is perfect for a sit down family meal or get together with a few friends',
#  'not much flavor to them and very portly constructed',
#  'the ratio seating was very comfortable',
#  'the fried rice was dry as we',
#  'hands down my favorite italian',
#  'that just screams left in my boy somewhat s also pretty rare here in began',
#  'it was just not a fun experience',
#  'the atmosphere was great with a lovely do of violinists playing songs we requested',
#  'i personal love the human pity balaga falafels and baby ganoush it s amazing what they do with plant',
#  'very convenient since we were staying at the mmm',
#  'the owners are super friendly and the is courteous',
#  'both great',
#  'electric selection',
#  'the set potato toes were god but the onion rings were perfection or as close as i have had',
#  'the was very attentive',
#  'and the chef was generous with his time even came around twice so we can take pictures with him',
#  'the owner used to work at not so this is really similar for half the price',
#  'gone mediocre and i imagine smashburger will pop up',
#  'dont go here',
#  'i promise they won t disappoint',
#  'as a such lover avoid this by al means',
#  'what a great double cheseburger',
#  'awesome and for',
#  'a fantastic neighborhood gem',
#  'i can t wait to go back',
#  'the planting were the worst i ve ever tasted',
#  'it s a great and i highly recommend it',
#  'was slow and not attentive',
#  'i gave it stars then and i m giving it stars now',
#  'your spends more time talking to themselves than me',
#  'desert papa coat was amazing',
#  'very god for great atmosphere',
#  'damn god speak',
#  'total branch fail',
#  'prices are very reasonable favors are spot on the sauce is home made and the saw is not drenched in mayo',
#  'the door is nice and the piano music soundtrack is pleasant',
#  'the speak was amazing re file relent was the best seated plate i have ever had',
#  'god for god',
#  'it was absolutely amazing',
#  'i probably won t be back to be honest',
#  'will definitely be back',
#  'the sergeant paper be sandwich with aunt sauce is an excellent sandwich as we',
#  'hawaiian breeze mange magic and pineapple delight are the smother that i ve tried so far and they re al god',
#  'went for lunch was slow',
#  'we had so much to say about the before we walked in that he expected it to be amazing but was quickly disappointed',
#  'i was mortified',
#  'needles to say we will never be back here again',
#  'anyway the for was definitely not filing at al and for the price you pay you should expect more',
#  'the chips that came out were driving with grease and mostly not enable',
#  'i wasn t really impressed with strip speak',
#  'have ben going since and every meal has ben awesome',
#  'our was very nice and attentive as were the other serving',
#  'the cashier was friendly and even brought the for out to me',
#  'i work in the hospitality industry in paradise valley and have refrained from recommending city any longer',
#  'the atmosphere here is fun',
#  'would not recommend to others',
#  'is quick and even to go orders are just like we like it',
#  'i mean really how do you get so famous for your fish and chips when it s so terrible',
#  'that said our mouths and belief were still quite pleased',
#  'not my thing',
#  'thumbs up',
#  'if you are reading this please don t go there',
#  'i loved the cried liza reminded me of left italian liza',
#  'only pro large seating area nice bar area great simple drink the best brick oven liza with homemade dough',
#  'they have a really nice atmosphere',
#  'tonight i had the ely file special and it sucked',
#  'after one bite i was hoped',
#  'we ordered some old class and some new dishes after going there a few times and were sorely disappointed with everything',
#  'cut quaint simple honest',
#  'the chicken was delicious seasoned and had the perfect cry on the outside and moist chicken on the inside',
#  'the for was great as always compliments to the chef',
#  'special thanks to plan t for the recommendation on what to order al yuma for my they',
#  'awesome selection of be',
#  'great for and awesome',
#  'one nice thing was that they added gratuity on the bill since our party was larger than or and they didn t expect more tip than that',
#  'a fly was in my able juice a fly',
#  'the had nan chicken was also very taste',
#  'as for the i thought it was god',
#  'the for was barely lukewarm so it must have ben sitting waiting for the to bring it out to us',
#  'ran s bar is definitely one edinburgh establishment i won t be visiting',
#  'nicest chinese i ve ben in a while',
#  'overall i like there for and the',
#  'they also now serve indian nan bread with human and some spice pine nut sauce that was out of this world',
#  'probably never coming back and wouldn t recommend it',
#  'friend s past also bad he barely touched it',
#  'try them in the airport to experience some taste for and speedy friendly',
#  'i love the door with the chinese caligraphy was paper',
#  'never had anything to complain about here',
#  'the is very clean and has a family felt to it',
#  'it was way over fried',
#  'i m not sure how long we stood there but it was long enough for me to begin to felt awkwardly out of',
#  'when i opened the sandwich i was impressed but not in a god way',
#  'will not be back',
#  'there was a warm feeling with the and i felt like their guest for a special treat',
#  'an extensive provides lots of option for breakfast',
#  'i always order from the vegetarian during dinner which has a wide away of option to chose from',
#  'i have watched their prices inflated portions get smaller and management attitudes grow rapidly',
#  'wonderful ll taras and the absence made me felt al warm and fury inside',
#  'i got to enjoy the seated salad with a fabulous vinegrete',
#  'the wanton were thin not thick and chew almost melt in your mouth',
#  'level spice was perfect where spice didn t over helm the soup',
#  'we were sat right on time and our from the get go was fantastic',
#  'main thing i didn t enjoy is that the crowd is of older crowd around mid s and up',
#  'when i m on this side of town this will definitely be a spot i l hit up again',
#  'i had to wait over minutes to get my drink and longer to get areas',
#  'this is a great to eat',
#  'the jalapeno bacon is so god',
#  'the was for and that being nice',
#  'for was god was god prices were god',
#  'the was not clean and the for oh so stale',
#  'the chicken dishes are ok the be is like shoe leather',
#  'but the was beyond bad',
#  'i m so happy to be here',
#  'tasted like dirt',
#  'one of the few places in phoenix that i would definitely go back to again',
#  'the block was amazing',
#  'it s close to my house it s low key non fancy adorable prices god for',
#  'both the hot sour the eg flower soups were absolutely stars',
#  'my sashimi was for quality being so and tastes',
#  'great time family dinner on a sunday night',
#  'the for is not taste at al not to say its real traditional human style',
#  'what did bother me was the slow',
#  'the flair bartenders are absolutely amazing',
#  'their frozen margaritas are way to sugary for my taste',
#  'these were so god we ordered them twice',
#  'so in a nutshell the restraint smell like a combination of a dirty fish market and a fewer',
#  'my girlfriend s veal was very bad',
#  'unfortunately it was not god',
#  'i had a pretty satisfying experience',
#  'join the club and get awesome offers via email',
#  'perfect for someone me who only likes be ice cold or in this case even colder',
#  'bland and flavorles is a god way of describing the barely tepid meat',
#  'the chains which i m no fan of beat this easily',
#  'the anchor are a must have',
#  'we will not be coming back',
#  'i don t have very many words to say about this but it does everything pretty we',
#  'the is super nice and very quick even with the crazy crowds of the downtown furies lawyers and court',
#  'great atmosphere friendly and fast',
#  'when i received my pity it was huge it did have a lot of meat in it so thumbs up there',
#  'once your for arises it s me',
#  'paying for a hot dog and fires that loss like it came out of a kid s meal at the wienerschnitzel is not my idea of a god meal',
#  'the classic maine lobster vol was fantastic',
#  'my brother in law who works at the mal ate here same day and guns what he was sick al night to',
#  'so god i am going to have to review this twice once whereas a tribute to the and once as a tribute to an event held here last night',
#  'the chips and also were really god the also was very fresh',
#  'this is great',
#  'mediocre for',
#  'once you get inside you l be impressed with the',
#  'i m super his',
#  'and was super friendly',
#  'why are these sad little vegetables so overcome',
#  'this was such a nice surprise',
#  'they were golden crisp and delicious',
#  'i had high hopes for this since the burghers are choked over a charcoal girl but unfortunately the taste felt flat way flat',
#  'i could eat their bruscheta al day it is divine',
#  'not a single employe came out to se if we were ok or even need a water refill once they finally served us our for',
#  'lastly the mozarela sticks they were the best thing we ordered',
#  'the first time i ever came here i had an amazing experience i still tell people how awesome the duck was',
#  'the was very negligent of our news and made us felt very unwelcome i would not suggest this',
#  'the was terrible though',
#  'this is overpriced not consistent with their bob and it really is overpriced',
#  'it was packed',
#  'i love this',
#  'i can say that the deserts were yuma',
#  'the for was terrible',
#  'the seasonal fruit was fresh white each pure',
#  'it kept getting worse and worse so now i m official done',
#  'this should honestly be blown up',
#  'but i definitely would not eat here again',
#  'do not waste your money here',
#  'i love that they put their for in nice plastic container as opposed to framing it in little paper takeout boxes',
#  'the or pe was delicate and thin and moist',
#  'awful',
#  'won t ever go here again',
#  'for quality has ben horrible',
#  'for that price i can think of a few i would have much rather gone',
#  'the here is fair at best',
#  'i do love such but i found kabuki to be over prices over hip and under services',
#  'do yourself a favor and stay away from this dish',
#  'very for',
#  'no one at the table thought the for was above average or worth the wait that we had for it',
#  'best and for ever maria our was so god and friendly she made our day',
#  'they were excellent',
#  'i paid the bill but did not tip because i felt the did a terrible job',
#  'just had lunch here and had a great experience',
#  'i have never had such bland for which surprised me considering the article we read focused so much on their spaces and flavor',
#  'for is way overpriced and portions are fucking small',
#  'i recently tried cabalero s and i have ben back every we since',
#  'for bucks a head i really expect better for',
#  'the for came out at a god pace',
#  'i ate there twice on my last visit and especially enjoyed the salmon salad',
#  'i won t be back',
#  'we could not believe how dirty the mystery were',
#  'this deserves no stars',
#  'i would not recommend this',
#  'in fact i m going to round up to stars just because she was so awesome',
#  'to my disbelieve each dish qualified as the worst version of these folds i have ever tasted',
#  'bad day or not i have a very low tolerable for rude customer people it is your job to be nice and polite wash dishes otherwise',
#  'the potatoes were great and so was the biscuit',
#  'i probably would not go here again',
#  'so flavorful and has just the perfect amount of heat',
#  'the price is reasonable and the is great',
#  'the wife hated her meal coronet shrimp and our friends really did not enjoy their meals either',
#  'my felt got the huevos ranchers and they didn t look to appealing',
#  'went in for happy hour great list of wines',
#  'some may say this but is prices but i think you get what you pay for and this you are getting quite a lot',
#  'i probably won t be coming back here',
#  'worst for i ve had in a while',
#  'this is pretty god nice little vice in the',
#  'talk about great customer of course we will be back',
#  'hot dishes are not hot cold dishes are close to from hemp i watched prepare for with bare hands no gloves everything is de fried in oil',
#  'i love their fires and their beans',
#  'always a pleasure dealing with him',
#  'they have a plethoric of salad and sandwiched and everything i ve tried gets my seal of approval',
#  'this is awesome if you want something light and healthy during the summer',
#  'for such on the strip this is the to go',
#  'the was great even the manager came and helped with our table',
#  'the felt of the dining from was more college coming course than high class dining and the was slow at best',
#  'i started this review with two stars but i m editing it to give it only one',
#  'this is the worst such i have ever eat besides costo s',
#  'al in al an excellent highlight by great a unique and a beautiful seeing',
#  'my boyfriend and i sat at the bar and had a completely delightful experience',
#  'weird vice from owners',
#  'there was hardly any meat',
#  'i ve had better wages from the grocer store',
#  'go to for gros',
#  'i love the owner chef his one authentic japanese col due',
#  'now the burghers aren t as god the liza which used to be amazing is doughy and flavorles',
#  'i found a six inch long piece of wire in my also',
#  'the was terrible for was mediocre',
#  'we definitely enjoyed ourselves',
#  'i ordered albondigas soup which was just warm and tasted like tomato soup with frozen metals',
#  'on the different occasions i asked for we done or medium we and al the times i got the bodies piece of meat on my plate',
#  'i had about two bites and refused to eat anymore',
#  'the was extremely slow',
#  'after minutes wait i got a table',
#  'seriously killer hot chair late',
#  'no clergy warnings on the and the waited had absolutely no clue as to which meals did or did not contain peanuts',
#  'my boyfriend tried the mediterranean chicken salad and felt in love',
#  'their rotating berg on tap is also a highlight of this',
#  'pricking is a bit of a concern at below mushroom',
#  'worst that ever',
#  'if you stay in began you must get breakfast here at least once',
#  'i want to first say our was great and we had perfect',
#  'the liza selections are god',
#  'i had strawberry tea which was god',
#  'highly unprofesional and rude to a loyal patron',
#  'overall a great experience',
#  'spend your money elsewhere',
#  'their regular boasted bread was equal satisfying with the occasional parts of outer m',
#  'the but at belagio was far from what i anticipated',
#  'and the drinks are weak people',
#  'my order was not correct',
#  'also i felt like the chips are bought not made in house',
#  'after the disappointing dinner we went elsewhere for desert',
#  'the chips and says a here is amazing',
#  'we won t be returning',
#  'this is my new far began but spot',
#  'i seriously cannot believe that the owner has so many inexperienced employed that al are running around like chickens with their heads cut of',
#  'very very sad',
#  'i felt insulted and disrespected how could you talk and judge another human being like that',
#  'how can you cal yourself a steakhouse if you can t properly co a speak i don t understand',
#  'i m not impressed with the concept or the for',
#  'the only thing i wasn t to crazy about was their guacamole as i don t like it our ed',
#  'there is really nothing for me at portions hope your experience is better',
#  'i got for poisoning here at the but',
#  'they brought a fresh batch of fires and i was thinking may something warm but no',
#  'what should have ben a hilarious yuma christmas eve dinner to remember was the digest fail of the entire trip for us',
#  'needles to say i won t be going back daytime son',
#  'this is disgusting',
#  'every time i eat here i se daring tearworn to a professional degree',
#  'the ri style calamari was a joke',
#  'however there was so much garlic in the tongue it was barely enable',
#  'i could barely stomach the meal but didn t complain because it was a business lunch',
#  'it was so bad i had lost the heart to finish it',
#  'it also to her forever to bring us the check when we asked for it',
#  'we aren t ones to make a scene at but i just don t get it definitely lost the love after this one',
#  'disappointing experience',
#  'the for is about on par with deny s which is to say not god at al',
#  'if you want to wait for mediocre for and downright terrible then this is the for you',
#  'way over rate is al i am saying',
#  'we won t be going back',
#  'the was fairly clean but the for simply wasn t worth it',
#  'this lacked style',
#  'the ganglia was about half of a glad wine full and was ridiculous',
#  'don t bother coming here',
#  'the meat was pretty dry i had the slice brisker and pulled pork',
#  'the building itself seems pretty neat the bathroom is pretty trip but i wouldn t eat here again',
#  'it was equal awful',
#  'probably not in a hurry to go back',
#  'very slow at seating even with reservation',
#  'not god by any stretch of the imagination',
#  'the cases cream sauce was bland and the vegetables were undercoked',
#  'the chipolte ranch dining cause was tastes seemed thin and watered down with no heat',
#  'it was a bit to set not really spice enough and lacked flavor',
#  'i was very disappointed',
#  'this is horrible and way overpriced',
#  'maybe it s just their vegetarian fare but i ve ben twice and i thought it was average at best',
#  'it wasn t busy at al and now we know why',
#  'the tables outside are also dirty a lot of the time and the workers are not always friendly and helpful with the',
#  'the alliance here did not felt like a but seeing but more of a douched indoor garden for tea and biscuits',
#  'con spot',
#  'the fires were not hot and neither was my burgher',
#  'but then they came back cold',
#  'then our for came out disappointment ensued',
#  'the real disappointment was our waiter',
#  'my husband said she was very rude did not even apologize for the bad for or anything',
#  'the only reason to eat here would be to fig up before a night of tinge drinking just to get some carts in your stomach',
#  'insults profound deuchebagery and had to go outside for a smoke break while serving just to solidity it',
#  'if someone orders two faces don t you think it may be part of customer to ask if it is comb or all cart',
#  'she was quite disappointed although some blame news to be placed at her for',
#  'after al the have reviews i couldn t wait to eat here what a disappointment',
#  'del tact is pretty nasty and should be avoided if possible',
#  'it s not hard to make a decent hamburg',
#  'but i don t like it',
#  'he no will i go back',
#  'we ve have gotten a much better from the liza next for than the services we received from this',
#  'i don t know what the big deal is about this but i won t be back a al',
#  'i immediately said i wanted to talk to the manager but i did not want to talk to the guy who was doing shots of firebal behind the bar',
#  'the alliance isn t much better',
#  'unfortunately it only set us up for disappointment with our enters',
#  'the for wasn t god',
#  'your serves suck wait correction our hosmer sucked',
#  'what happened next was pretty of putting',
#  'to bad cause i know it s family owned i really wanted to like this',
#  'overpriced for what you are getting',
#  'i vomited in the bathroom mid lunch',
#  'i kept looking at the time and it had son become minutes yet still no for',
#  'i have ben to very few places to eat that under no circumstances would i ever return to and this tops the list',
#  'we started with the tune sashimi which was brownish in color and obviously wasn t fresh',
#  'for was below average',
#  'it sure does beat the anchor at the moves but i would expect a little bit more coming from a',
#  'al in al ha long bay was a bit of a flop',
#  'the problem i have is that they charge for a sandwich that is no bier than a subways sub which offers better and more amount of vegetables',
#  'shrimp when i unwrapped it i live only a mile from brushfire it was literary ice cold',
#  'it lacked flavor seemed undercoked and dry',
#  'it really is impressive that the hasn t closed down',
#  'i would avoid this if you are staying in the manage',
#  'the replied beans that came with my meal were dried out and crusty and the for was bland',
#  'spend your money and time some else',
#  'a lady at the table next to us found a live grew caterpilar in her salad',
#  'the presentation of the for was awful',
#  'i can t tell you how disappointed i was',
#  'i think for should have flavor and texture and both were lacking',
#  'appetite instantly gone',
#  'overall i was not impressed and would not go back',
#  'the whole experience was underwhelming and i think we l just go to nina such next time',
#  'then as if i hadn t wasted enough of my life there they poured salt in the wound by drawing out the time it to to bring the check']

# %% [markdown]
# ## Creating the Bag of Words model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features= 1300)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:,-1].values

# %%
len(X[0])
# Out:
# 1300

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ## Training the pipeline models on the Training set

# %%
# Modified Sampling 900-1100 Pipeline
XGBoost_pipeline = ImbPipeline([
    ('classifier', XGBClassifier())])

#Modified model to randomforest
random_forest_pipeline = ImbPipeline([
    ('classifier', RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42))])

logistic_reg_pipeline = ImbPipeline([
    ('classifier', LogisticRegression())])

naive_bayes_pipeline = ImbPipeline([
    ('classifier', GaussianNB())])

svm_pipeline = ImbPipeline([
    ('classifier', SVC(probability=True))])

gradient_boost_pipeline = ImbPipeline([
    ('classifier', GradientBoostingClassifier(random_state=42))])

knn_pipeline = ImbPipeline([
    ('classifier', KNeighborsClassifier(n_neighbors=5))])

# %%
# Define the pipelines
pipelines_to_compare = {
    'XGBoost Pipeline': XGBoost_pipeline,
    'Random Forest Pipeline': random_forest_pipeline,
    'Logistic Regression Pipeline': logistic_reg_pipeline,
    'Naive Bayes Pipeline': naive_bayes_pipeline,
    'Support Vector Machine Pipeline': svm_pipeline,
    'Gradient Boost Pipeline': gradient_boost_pipeline,
    'KNN Pipeline': knn_pipeline
}

results = {}

for name, pipeline in pipelines_to_compare.items():
    print(f"\nEvaluating {name} on X_train...")

    # Train the pipeline
    pipeline.fit(X_train, y_train)

    # Predict on test data
    y_pred = pipeline.predict(X_train)
    y_pred_proba = pipeline.predict_proba(X_train)[:, 1]

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_train, y_pred)


    # Store results
    results[name] = {
        'Accuracy': accuracy,
    }


# Display results for comparison
results_df = pd.DataFrame(results).T

print("Pipeline Comparison Results:")
display(results_df)
# Out:
# Evaluating XGBoost Pipeline on X_train...
#
# Evaluating Random Forest Pipeline on X_train...
#
# Evaluating Logistic Regression Pipeline on X_train...
#
# Evaluating Naive Bayes Pipeline on X_train...
#
# Evaluating Support Vector Machine Pipeline on X_train...
#
# Evaluating Gradient Boost Pipeline on X_train...
#
# Evaluating KNN Pipeline on X_train...
# Pipeline Comparison Results:
#                                  Accuracy
# XGBoost Pipeline                  0.94000
# Random Forest Pipeline            0.98500
# Logistic Regression Pipeline      0.97000
# Naive Bayes Pipeline              0.89750
# Support Vector Machine Pipeline   0.97125
# Gradient Boost Pipeline           0.88625
# KNN Pipeline                      0.77750

# %% [markdown]
# ## Predicting the Test set results & making the Confusion Matrix

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# Evaluate the pipelines on the test set
for name, pipeline in pipelines_to_compare.items():
    print(f"\nEvaluating {name} on X_test...")

    # Predict on the test set
    y_test_pred = pipeline.predict(X_test)

    # Calculate evaluation metrics
    test_accuracy = accuracy_score(y_test, y_test_pred)
    conf_matrix = confusion_matrix(y_test, y_test_pred)

    # Print the results
    print(f"Accuracy: {test_accuracy *100}% ")
    print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Evaluating XGBoost Pipeline on X_test...
# Accuracy: 77.0%
# Confusion Matrix:
# [[82 15]
#  [31 72]]
#
# Evaluating Random Forest Pipeline on X_test...
# Accuracy: 77.0%
# Confusion Matrix:
# [[86 11]
#  [35 68]]
#
# Evaluating Logistic Regression Pipeline on X_test...
# Accuracy: 82.0%
# Confusion Matrix:
# [[82 15]
#  [21 82]]
#
# Evaluating Naive Bayes Pipeline on X_test...
# Accuracy: 68.5%
# Confusion Matrix:
# [[52 45]
#  [18 85]]
#
# Evaluating Support Vector Machine Pipeline on X_test...
# Accuracy: 79.5%
# Confusion Matrix:
# [[82 15]
#  [26 77]]
#
# Evaluating Gradient Boost Pipeline on X_test...
# Accuracy: 73.5%
# Confusion Matrix:
# [[87 10]
#  [43 60]]
#
# Evaluating KNN Pipeline on X_test...
# Accuracy: 60.0%
# Confusion Matrix:
# [[64 33]
#  [47 56]]

# %% [markdown]
# ## Used to predict a single review.

# %%
# Single review for prediction
new_review = 'I hate this restaurant so much'

# Clean the review (same preprocessing as in the training corpus)
new_review = re.sub('[^a-zA-Z]', ' ', new_review)
new_review = new_review.lower()
new_review = new_review.split()
ps = PorterStemmer()
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
new_review = [ps.stem(word) for word in new_review if word not in set(all_stopwords)]
new_review = ' '.join(new_review)

# Transform the review into the same format as the training data
new_corpus = [new_review]
new_X_test = cv.transform(new_corpus).toarray()

# Predict using the Logistic Regression Pipeline
new_y_pred = logistic_reg_pipeline.predict(new_X_test)

# Output the result
if new_y_pred[0] == 1:
    print("The sentiment of the review is: Positive")
else:
    print("The sentiment of the review is: Negative")
# Out:
# The sentiment of the review is: Negative
